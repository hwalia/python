# %%
4
# Out:
# 4

# %%
print("first live learning session")
# Out:
# first live learning session

# %%
(2.0) ** (1/2)
# Out:
# 1.4142135623730951

# %%
degree_celsius = 25

# %%
degree_celsius
# Out:
# 25

# %%
degree_fahrenheit = (9/5) * degree_celsius + 32

# %%
degree_fahrenheit
# Out:
# 77.0

# %%
type(degree_celsius)
# Out:
# int

# %%
degree_celsius = degree_celsius * 1.0

# %%
degree_celsius
# Out:
# 25.0

# %%
type (degree_celsius)
# Out:
# float

# %%
degree_celsius = degree_celsius * 1

# %%
degree_celsius
# Out:
# 25.0

# %%
a = 3

# %%
a+=4

# %%
a
# Out:
# 9

# %%
a**=4

# %%
a
# Out:
# 6561

# %%
a+= 4

# %%
a =2

# %%
a**= 4

# %%
round (3.55, 7)
# Out:
# 3.55
